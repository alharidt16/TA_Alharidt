# %%
import kmedoids

# %%
from sklearn.metrics import pairwise_distances
import numpy as np
import pandas as pd

# %%
# generate some random data
dataku=pd.read_csv("Dataclean.csv")
dataku
# Out:
#           Kabupaten/Kota Nama Kepala Rumah Tangga   X1  X2  X3  X4  X5  X6  \
# 0        KOTA BANDA ACEH             WAHYU HIDAYAT   1   1   1   2   1   1
# 1        KOTA BANDA ACEH                    MUCHRI   2   1   1   6   1   2
# 2        KOTA BANDA ACEH                 USMAN ALI   1   1   1   6   1   1
# 3        KOTA BANDA ACEH                    EFENDI   1   1   1   6   1   1
# 4        KOTA BANDA ACEH               FARIDAHWATI   1   2   4   6   1   1
# ...                  ...                       ...  ..  ..  ..  ..  ..  ..
# 60744  KOTA SUBULUSSALAM             DANI SAPUTERA   1   3   4   6   1   2
# 60745  KOTA SUBULUSSALAM                  SULASTRI   1   1   1   6   3   2
# 60746  KOTA SUBULUSSALAM                     KARDA   1   1   1   6   3   2
# 60747  KOTA SUBULUSSALAM                 SUWARSONO   1   1   1   6   1   1
# 60748  KOTA SUBULUSSALAM                   PURNOMO   1   5   4   6   3   2
#
# ...

# %%
dataku
dataku=dataku.drop(["Kabupaten/Kota","Nama Kepala Rumah Tangga","Y","Unnamed"], axis=1)
dataku
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Alharidt\Documents\GitHub\TA_Alharidt\coba.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/coba.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> dataku
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/coba.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> dataku=dataku.drop(["Kabupaten/Kota","Nama Kepala Rumah Tangga","Y","Unnamed"], axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/coba.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> dataku
#
# File c:\Users\Alharidt\miniconda3\lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
# ...

# %%
# create a KMedoids object with 5 clusters
kmedoids = kmedoids(n_clusters=5, metric='manhattan')

# %%
# fit the model to the data
kmedoids.fit(data)

# %%
# view the cluster labels
print(kmedoids.labels_)

# view the medoids
print(kmedoids.medoids_)
