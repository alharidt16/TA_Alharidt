# %%
import kmedoids

# %%
from sklearn.metrics import pairwise_distances
import numpy as np
import pandas as pd

# %%
# generate some random data
dataku=pd.read_csv("Dataclean.csv")
dataku
# Out:
#           Kabupaten/Kota Nama Kepala Rumah Tangga   X1  X2  X3  X4  X5  X6  \
# 0        KOTA BANDA ACEH             WAHYU HIDAYAT   1   1   1   2   1   1
# 1        KOTA BANDA ACEH                    MUCHRI   2   1   1   6   1   2
# 2        KOTA BANDA ACEH                 USMAN ALI   1   1   1   6   1   1
# 3        KOTA BANDA ACEH                    EFENDI   1   1   1   6   1   1
# 4        KOTA BANDA ACEH               FARIDAHWATI   1   2   4   6   1   1
# ...                  ...                       ...  ..  ..  ..  ..  ..  ..
# 60744  KOTA SUBULUSSALAM             DANI SAPUTERA   1   3   4   6   1   2
# 60745  KOTA SUBULUSSALAM                  SULASTRI   1   1   1   6   3   2
# 60746  KOTA SUBULUSSALAM                     KARDA   1   1   1   6   3   2
# 60747  KOTA SUBULUSSALAM                 SUWARSONO   1   1   1   6   1   1
# 60748  KOTA SUBULUSSALAM                   PURNOMO   1   5   4   6   3   2
#
#        X7  X8  ...  X26  X27  X28  X29  X30  X31  X32  X33  X34  Y
# ...

# %%
dataku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60749 entries, 0 to 60748
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Kabupaten/Kota             60749 non-null  object
#  1   Nama Kepala Rumah Tangga   60749 non-null  object
#  2   X1                         60749 non-null  int64
#  3   X2                         60749 non-null  int64
#  4   X3                         60749 non-null  int64
#  5   X4                         60749 non-null  int64
#  6   X5                         60749 non-null  int64
#  7   X6                         60749 non-null  int64
#  8   X7                         60749 non-null  int64
#  9   X8                         60749 non-null  int64
#  10  X9                         60749 non-null  int64
#  11  X10                        60749 non-null  int64
#  12  X11                        60749 non-null  int64
# ...

# %%
dataku
dataku=dataku.drop(["Kabupaten/Kota","Nama Kepala Rumah Tangga ","Y"], axis=1)
dataku
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...  X25  X26  X27  X28  X29  \
# 0       1   1   1   2   1   1   6   1   2    2  ...    2    1    2    2    2
# 1       2   1   1   6   1   2   6   2   1    2  ...    1    1    2    2    2
# 2       1   1   1   6   1   1   6   1   1    2  ...    2    1    2    2    2
# 3       1   1   1   6   1   1   6   1   1    2  ...    2    1    2    2    2
# 4       1   2   4   6   1   1   6   1   2    3  ...    2    2    2    2    2
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 60744   1   3   4   6   1   2   6   2   2    7  ...    2    2    2    2    2
# 60745   1   1   1   6   3   2   6   2   1    7  ...    2    2    2    2    2
# 60746   1   1   1   6   3   2   6   2   2    7  ...    2    2    2    2    2
# 60747   1   1   1   6   1   1   6   1   3    6  ...    2    1    1    2    2
# 60748   1   5   4   6   3   2   6   2   2    7  ...    2    2    2    2    2
#
#        X30  X31  X32  X33  X34
# ...

# %%
# !pip install kmedoids

# %%
from kmedoids import KMedoids

# %%
k_medoids = KMedoids(n_clusters=5)
k_medoids.fit(dataku)
#plot_graphs(data, k_medoids)
# Out:
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 k_medoids = KMedoids(n_clusters=5)
# ----> 2 k_medoids.fit(dataku)
#
# File ~\miniconda3\lib\site-packages\kmedoids\__init__.py:928, in KMedoids.fit(self, X, y)
#     926 	X = pairwise_distances(X, metric=self.metric)
#     927 if self.method == "fasterpam":
# --> 928 	result = fasterpam(X, self.n_clusters, self.max_iter, self.init, random_state=self.random_state)
#     929 elif self.method == "fastpam1":
#     930 	result = fastpam1(X, self.n_clusters, self.max_iter, self.init, random_state=self.random_state)
#
# File ~\miniconda3\lib\site-packages\kmedoids\__init__.py:254, in fasterpam(diss, medoids, max_iter, init, random_state, n_cpu)
#     252 		return KMedoidsResult(*_par_fasterpam_i32(diss, medoids.astype(np.uint64), max_iter, seed, n_cpu))
#     253 	elif dtype == np.int64:
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 k_medoids = KMedoids(n_clusters=5, init='random')
# ----> 2 k_medoids.fit(dataku)
#
# File ~\miniconda3\lib\site-packages\kmedoids\__init__.py:928, in KMedoids.fit(self, X, y)
#     926 	X = pairwise_distances(X, metric=self.metric)
#     927 if self.method == "fasterpam":
# --> 928 	result = fasterpam(X, self.n_clusters, self.max_iter, self.init, random_state=self.random_state)
#     929 elif self.method == "fastpam1":
#     930 	result = fastpam1(X, self.n_clusters, self.max_iter, self.init, random_state=self.random_state)
#
# File ~\miniconda3\lib\site-packages\kmedoids\__init__.py:254, in fasterpam(diss, medoids, max_iter, init, random_state, n_cpu)
#     252 		return KMedoidsResult(*_par_fasterpam_i32(diss, medoids.astype(np.uint64), max_iter, seed, n_cpu))
#     253 	elif dtype == np.int64:
# ...

# %%
# fit the model to the data
kmedoids.fit(data)

# %%
# view the cluster labels
print(kmedoids.labels_)

# view the medoids
print(kmedoids.medoids_)
