# %%
import pandas as pd

# %%
data=pd.read_csv("Data_gabung _filter 2.csv")

# %%
data
# Out:
#                     KOTA Nama Kepala Rumah Tangga (KRT)  \
# 0        KOTA BANDA ACEH                  WAHYU HIDAYAT
# 1        KOTA BANDA ACEH                         MUCHRI
# 2        KOTA BANDA ACEH                      USMAN ALI
# 3        KOTA BANDA ACEH                         EFENDI
# 4        KOTA BANDA ACEH                    FARIDAHWATI
# ...                  ...                            ...
# 60767  KOTA SUBULUSSALAM                  DANI SAPUTERA
# 60768  KOTA SUBULUSSALAM                       SULASTRI
# 60769  KOTA SUBULUSSALAM                          KARDA
# 60770  KOTA SUBULUSSALAM                      SUWARSONO
# 60771  KOTA SUBULUSSALAM                        PURNOMO
#
#        Jumlah Anggota Rumah Tangga (ART)  Jumlah Keluarga  \
# 0                                      3                1
# 1                                      5                2
# 2                                      1                1
# ...

# %%
DATA=data.drop(["KOTA","Nama Kepala Rumah Tangga (KRT)","Status Kesejahteraan"], axis=1)
DATA
# Out:
#        Jumlah Anggota Rumah Tangga (ART)  Jumlah Keluarga  \
# 0                                      3                1
# 1                                      5                2
# 2                                      1                1
# 3                                      2                1
# 4                                      1                1
# ...                                  ...              ...
# 60767                                  3                1
# 60768                                  1                1
# 60769                                  4                1
# 60770                                  3                1
# 60771                                  3                1
#
#        Status bangunan tempat tinggal  Status lahan tempat tinggal  \
# 0                                   1                            1
# 1                                   1                            1
# ...

# %%
from scipy.cluster.vq import KMedians
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Alharidt\Documents\GitHub\TA_Alharidt\Untitled.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/Untitled.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from scipy.cluster.vq import KMedians
#       <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/Untitled.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#
# ImportError: cannot import name 'KMedians' from 'scipy.cluster.vq' (C:\Users\Alharidt\AppData\Roaming\Python\Python311\site-packages\scipy\cluster\vq.py)

# %%
# Create k-medians algorithm instance.
centroids, _ = kmedians(DATA, 2)

print(centroids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Alharidt\Documents\GitHub\TA_Alharidt\Untitled.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Create k-medians algorithm instance.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> centroids, _ = kmedians(DATA, 2)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alharidt/Documents/GitHub/TA_Alharidt/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> print(centroids)
#
# NameError: name 'kmedians' is not defined
